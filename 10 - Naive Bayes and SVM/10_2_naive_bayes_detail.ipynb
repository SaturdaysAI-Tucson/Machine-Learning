# %% [markdown]
# # Naive Bayes
#
# Naive Bayes refers to the use of Bayes' theorem with naive independence assumptions between features.
#
# Naive Bayes classifers are popular for categorizing text. The goal of this module is to learn the basics of Naive Bayes and the ways Naive Bayes is improved for the purposes of sentiment analysis. The module is split into a few sections:
#
# + Prepare the data for analysis
# + Introduction to Naive Bayes
# + Improvement 1: Dealing with negation
# + Improvement 2: Bigrams
# + Improvement 3: Binary count Naive Bayes
# + Improvement 4: Dealing with Informal text
#
# This module coincides with our lecture on improving naive bayes for sentiment analysis.
#
# Before we delve into section 1 on data preparation, we will begin by doing an overview of the data we're using. For the reader's understanding of the methodology, we:
#
# 1. First, pulled the Twitter data related to microfinance using tweepy, a Twitter API library.
# 2. Next, we classified the comments into sentiment polarities in order to obtain training data for our model.
#     + Normally this process would require manually classifying ~20% of our data.
#     + In our exercise, we leveraged a simple wordnet algorithm called TextBlob to tag the entire data set.
# 3. We then manually reviewed and corrected classiications.
#     + (Note, if you are interested in seeing the code used to implement this, see the file titled "twitter_web_scraping.")

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline 

import string
import nltk
# if you have never done so, you need to download stopwords from nltk
#nltk.download('stopwords')
#nltk.download('wordnet')
from nltk.corpus import stopwords
from nltk.stem.wordnet import WordNetLemmatizer
from nltk.tokenize import TweetTokenizer
from sklearn.model_selection import train_test_split
import re
import itertools
from sklearn.feature_extraction.text import CountVectorizer

from sklearn.metrics import confusion_matrix
from sklearn.naive_bayes import MultinomialNB
from wordcloud import WordCloud

from nltk.sentiment.util import mark_negation
from nltk import word_tokenize

# %%
#load data
data = pd.read_csv("microfinance_tweets.csv", encoding="ISO-8859-1")

# %%
#load data by getting it from github, if using colab

# !git clone https://github.com/DeltaAnalytics/machine_learning_for_good_data
data = pd.read_csv("machine_learning_for_good_data/microfinance_tweets.csv", encoding="ISO-8859-1")

# %%
#check data to see if everything worked
data.head(10)
# Out:
#                                             Comments            Date  \
# 0  RT @atmadiprayET: Here's why Janalakshmi Finan...  3/22/2018 5:40
# 1  RT @ecosmob: Ecosmob's #Mobility solutions for...  3/22/2018 5:36
# 2  Project have big future! Microfinance is belie...  3/22/2018 5:27
# 3  #Online #Banking-  Yako Microfinance Bank prov...  3/22/2018 5:21
# 4  MICROFINANCE EVENT: 3rd BoP Global Network Sum...  3/22/2018 5:19
# 5  RT @FINCA: .@rupertscofield spoke with @techwe...  3/22/2018 5:08
# 6  Capacity building and knowledge management are...  3/22/2018 5:03
# 7  RT @oluabudu: Get a cash loan of N200,000 to N...  3/22/2018 5:00
# 8  RT @PoojaMedia: From being an influencer for a...  3/22/2018 4:59
# 9  RT @WhatWorksVAWG: Read latest blog from Erin ...  3/22/2018 4:58
#
#    Favorites                      User  Polarity Sentiment
# 0          0             Saloni Shukla -0.100000  negative
# 1          0        Sindhav Bhageerath -0.062500   neutral
# 2          0  Konstantin #savedroidICO  0.166667  positive
# 3          0          YakoMicrofinance  0.500000  positive
# 4          0              MicroCapital  0.045455  positive
# 5          0              Right Angles  0.000000   neutral
# 6          0          @barbara_zawedde  0.144444  positive
# 7          0                Tola Abudu  0.136364  positive
# 8          0                      idee  0.000000   neutral
# 9          0          Sofia Sprechmann  0.500000  positive

# %% [markdown]
# The Twitter data contains six columns:
# + Comments: the Twitter post that was made mentionining microfinance
# + Date: date the post was created on Twitter
# + Favorites: number of favorites the post has
# + User: name of the user who posted the comment
# + Polarity: the polarity, representing the degree of positivity versus negatvity that textblob deemed the post
# + Sentiment: a conversion of polarity into positive, negative, and neutral classifications
#
# Note that this exercise really does simulate what would happen in a real world situation. Our data is limited, and the process to get the quality training and test data we need (with labeled polarity) is a diffult one. To understand the nature of our data, we will conduct a few exercises below.

# %%
## What do we have for sentiment breakdown?
sns.countplot(x = 'Sentiment', data = data)
data['Sentiment'].value_counts()
# Out:
# neutral     1943
# positive    1039
# negative     259
# Name: Sentiment, dtype: int64

# %% [markdown]
# It looks like most people have positive or neutral comments about microfinance. In fact, the volume of negative comments is the most interesting and should be investigated further.

# %%
## What are these negative comments?

#format columns so comments don't get cut off
pd.set_option('display.max_columns', None) 

#pull negative comments
data.loc[data['Sentiment'] == 'negative']['Comments'].unique()[0:1]
# Out:
# array(["RT @atmadiprayET: Here's why Janalakshmi Financial takes so long to small finance bank transition https://t.co/traKQNXuxe via @economictime\x85"],
#       dtype=object)

# %% [markdown]
# It seems like some of the negative comments are not valid and should actually be classified as neutral. However, some of the negative comments are valid, e.g. illegal activity.
#
# Usually we would clean these classifications to correct it, but we will move forward to preparing our data for the model.

# %% [markdown]
# # Prepare data for the model
#
# The most common way to apply machine learning algorithms, such as Naive Bayes, to text analysis is to convert our text into numerical feature vectors that the algorithms can understand.
#
# The representation we will create is the **Bag of Words**. To get from our data, which is currently structured as a Series of strings, to a Bag of Words, we will **vectorize** our tweets.
#
# This **vectorization** of our text documents will require a few key steps, which we describe in more detail in [Module 8](https://docs.google.com/presentation/d/1vaxDuUROgaqix9Mfkyb4_h0cGkGwN7AUeLU1ozhtJW8/edit#slide=id.g227403103b_0_1171):
#
# Step 0. Split data into training and test sets (this is not part of vectorization) <br>
# Step 1. Clean and **tokenize** text <br>
# Step 2. Count the number of words in each document
#
# #### Step 0: Create training and test data
# This step should come naturally.
# We have classified sentiments for all our data, and we choose an 80-20 training and test split, with observations assigned at random.

# %%
# A) Create a set of test (20% of data) and training (80% of data) data
# We set a seed so this can be reproducible
np.random.seed(12345)
msk = np.random.rand(len(data)) < 0.8
train = data[msk]
test = data[~msk]

# %%
# Be sure to check the length of the training and test sets to confirm data was split in the correct porportions
print(len(train), len(test))
print("Split of {:.2%} train, {:.2%} test".format(len(train)/len(data), len(test)/len(data)))
# Out:
# 2594 647
# Split of 80.04% train, 19.96% test

# %% [markdown]
# #### Step 1: Clean and Tokenize Text
#
# As mentioned, the most common way to extract numerical vectors from text is to have a set of text **tokens** for which we can have counts.
#
# **Tokenization** means to convert a document/sentence/tweet into individual *tokens*, which are usually words, or word-like units.
#
# When creating these word-like tokens, we want to standardize them in a way that groups words with similar intent. This makes these token features more useful than unprocessed words. Check out the [NLP Module](https://docs.google.com/presentation/d/1vaxDuUROgaqix9Mfkyb4_h0cGkGwN7AUeLU1ozhtJW8/edit#slide=id.g227403103b_0_1050) for more details!
#
# We create a function to
# + **lemmatize** these words
# + remove *stop words*, punctuation, URLs, numbers, and special characters
#
# Luckily, NLTK has different libraries that make this task very easy.

# %%
# B) Lemmatize words, and remove stop words and punctuation
lemmatizer = WordNetLemmatizer()

def text_process(text):
    '''
    Takes in a string of text, then performs the following:
    1. Remove URLs
    2. Remove punctuation
    3. Remove numbers
    4. Remove stopwords
    5. Return the cleaned text as a list of lemmatized words
    '''
    
    text = re.sub(r'\w+:\/{2}[\d\w-]+(\.[\d\w-]+)*(?:(?:\/[^\s/]*))*', '', text, flags=re.MULTILINE)
    
    text = ''.join([t for t in text if t not in string.punctuation])
    
    text = ''.join([t for t in text if not t.isdigit()])
    
    return [lemmatizer.lemmatize(word) for word in text.split() if word.lower() not in stopwords.words('english')]

# %%
# Let's test the function to make sure it's doing what we would expect
sample_text = "I LOVE love BBQ chicken pizzas. I eat it every day, but sometimes I wonder if I'm being unhealthy https://ilove.pizza"
text_process(sample_text)
# Out:
# ['LOVE',
#  'love',
#  'BBQ',
#  'chicken',
#  'pizza',
#  'eat',
#  'every',
#  'day',
#  'sometimes',
#  'wonder',
#  'Im',
#  'unhealthy']

# %% [markdown]
# #### Step 2) Count the number of words in each 'document'
#
# This is the step that brings our text to the representation as a *Bag of Words*.
#
# A bag of words allows us to work with free text in a structured way. We use a simple count for our bag of words, but TF-IDF sklearn libraries are also available and can be used for other NLP problems.
#
# We use the **CountVectorization** function from the sklearn library.
#
# The TF-IDF Vectorizer is available by using:
#
# `from sklearn.feature_extraction.text import TfidfVectorizer`
#
# Note the difference in the use of the functions for fitting bag of words for test versus training data.

# %%
# C) Represent the text in a bag-of-words by leveraging CountVectorization in the sklearn library.
vectorizer = CountVectorizer(analyzer=text_process)
train_features = vectorizer.fit_transform(train['Comments'])
test_features =  vectorizer.transform(test['Comments'])

# %%
vectorizer.get_feature_names()[0:20]
# Out:
# ['AB',
#  'ABMFBNIGERIA',
#  'ACHT',
#  'ACT',
#  'ACTIVITIES',
#  'ADB',
#  'ADBHQ',
#  'ADCs',
#  'ADEL',
#  'AEX',
#  'AFG',
#  'AFSG',
#  'AGM',
#  'AGOTonga',
#  'AGm',
#  'AI',
#  'AID',
#  'ALIBABA',
#  'ALLEVIATION',
#  'AMCResearch']

# %% [markdown]
# These are our *features*, i.e. all of the cleaned tokens from all of the tweets. A training or test tweet can now be represented as a count of how many times any of these features shows up.

# %%
# Test the vectorizer by looking at the size of the vectors and snippets of the vectors
print('Length of Vectorizer Vocabulary: ', len(vectorizer.vocabulary_))
print('Shape of Sparse Matrix: ', test_features.shape)
print('Amount of Non-Zero occurrences: ', test_features.nnz)

# Percentage of non-zero values
density = 100.0 * (test_features.nnz / (test_features.shape[0] * test_features.shape[1]))
print('Density: {}'.format((density)))
# Out:
# Length of Vectorizer Vocabulary:  4890
# Shape of Sparse Matrix:  (647, 4890)
# Amount of Non-Zero occurrences:  6718
# Density: 0.21233757818846147

# %% [markdown]
# We have 4890 *tokens* in our corpus. The test data features matrix is a representation of each of the 647 tweets as a vector of token counts.

# %%
# To understand how the vectorizer stores words, we will input a sample test data review
sample_test = test['Comments'].iloc[0]
print("Sample comment: ", sample_test, "\n")
sample_vector = vectorizer.transform([sample_test])
print("Vectorization:")
print(sample_vector)
# Out:
# Sample comment:  RT @atmadiprayET: Here's why Janalakshmi Financial takes so long to small finance bank transition https://t.co/traKQNXuxe via @economictime
#
# Vectorization:
#   (0, 755)	1
#   (0, 925)	1
#   (0, 1090)	1
#   (0, 1780)	1
#   (0, 2487)	1
#   (0, 2530)	1
#   (0, 3000)	1
#   (0, 3179)	1
#   (0, 3667)	1
#   (0, 4391)	1
#   (0, 4533)	1
#   (0, 4640)	1
#   (0, 4727)	1

# %%
# This means we have a word count for a word at index 755, 925, etc.
# We can use get_feature_names() on the vectorizer to see what these words are
print(list(vectorizer.get_feature_names()[i] for i in sample_vector.indices))
# Out:
# ['Financial', 'Heres', 'Janalakshmi', 'RT', 'atmadiprayET', 'bank', 'economictime', 'finance', 'long', 'small', 'take', 'transition', 'via']

# %% [markdown]
# Let's look at a Wordcloud of our data to see what words are most frequently showing up!

# %%
cloud = WordCloud(width=1600, height=1200).generate(" ".join(data['Comments'].astype(str)))
plt.figure(figsize=(20, 15))
plt.imshow(cloud)
plt.axis('off')
# Out:
# (-0.5, 1599.5, 1199.5, -0.5)

# %% [markdown]
# We still appear to have some urls, and Telenor seems to be a big deal.

# %% [markdown]
# # Introduction to Naive Bayes
# We will begin by running Naive Bayes on the text and check how well it does in predicting classifications. This step is very easy given we have already prepared out data in a bag of words format. <br>

# %%
#train your data set using multinomial NB from sklearn library
nb = MultinomialNB()
nb.fit(train_features, train['Sentiment'])
# Out:
# MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)

# %%
#test your data set on your test data
preds = nb.predict(test_features)

#print the accuracy of your model
accuracy = (preds == test['Sentiment'])
'Accuracy : {:.2%}'.format(accuracy.sum() / len(accuracy))
# Out:
# 'Accuracy : 83.77%'

# %% [markdown]
# The accuracy is high at ~84%. Most sentiment analysis algorithms have an accuarcy of ~80% when you have fitted the model on proper training data. In this case, the 84% accuracy is likely inflated because we've used TextBlob to determine the correct sentiment in our training data.
#
# The current measurement of accuracy is a one-dimensional value. We don't know what we're messing up when we classify the sentiments wrong. One tool to better understand how we're misclassifying is called a confusion matrix (first introduced in module X: Logistic Regression.)

# %%
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
class_names = set(data['Sentiment'])
cnf_matrix = confusion_matrix(test['Sentiment'], preds)
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names,
                      title='Confusion matrix, basic NB')

plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names, normalize=True,
                      title='Normalized confusion matrix')
# Out:
# Confusion matrix, without normalization
# [[ 47   8   7]
#  [ 36 307  29]
#  [  4  21 188]]
# Normalized confusion matrix
# [[0.75806452 0.12903226 0.11290323]
#  [0.09677419 0.82526882 0.07795699]
#  [0.01877934 0.09859155 0.88262911]]

# %% [markdown]
# The above results show that we're commonly predicting positive comments as netural. This misclassification is not as concerning as our second common misclassification of negative comments as positive.

# %% [markdown]
# # Improvement 1: Dealing with Negation
#
# To improve on simple Naive Bayes for sentiment analysis, we can adjust our tokenizer for negation in sentences. (See module 10 lecture slides for full details.) Mark negation is a library we can use in NLTK that appends a "_NEG" to words after a negation until a punctuation mark. This means that the words after a negation will be handled differently than the words before a negation. We can investgate whether using negation will improve our model. Given wordnet did not classify negation properly, this method will unfortunately probably not improve the model.

# %%
# Example of mark_negation
print(mark_negation("I like BBQ chicken pizza . I like pepperoni pizza.".split()))
print(mark_negation("I don't like BBQ chicken pizza . I like pepperoni pizza only .".split()))
# Out:
# ['I', 'like', 'BBQ', 'chicken', 'pizza', '.', 'I', 'like', 'pepperoni', 'pizza.']
# ['I', "don't", 'like_NEG', 'BBQ_NEG', 'chicken_NEG', 'pizza_NEG', '.', 'I', 'like', 'pepperoni', 'pizza', 'only', '.']

# %%
# Test using mark_negation with text_process
text = "I don't like BBQ chicken pizza. I like pepperoni pizza only."
print(mark_negation(text_process(text)))
# Out:
# ['dont', 'like_NEG', 'BBQ_NEG', 'chicken_NEG', 'pizza_NEG', 'like_NEG', 'pepperoni_NEG', 'pizza_NEG']

# %%
# To incorporate it into our Naive Bayes model, we will need to adjust how we process our data in creating a bag of words
vectorizer_negation = CountVectorizer(analyzer='word', tokenizer = lambda text: mark_negation(text_process(text)))
train_features_negation = vectorizer_negation.fit_transform(train['Comments'])
test_features_negation = vectorizer_negation.transform(test['Comments'])

# %%
#train your data set using multinomial NB from sklearn library
nb = MultinomialNB()
nb.fit(train_features_negation, train['Sentiment'])
# Out:
# MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)

# %%
#test your data set on your test data
preds = nb.predict(test_features_negation)

#print the accuracy of your model
accuracy = (preds == test['Sentiment'])
'Accuracy : {:.2%}'.format(accuracy.sum() / len(accuracy))
# Out:
# 'Accuracy : 84.70%'

# %% [markdown]
# As predicted, using negation has not improved our accuracy.

# %% [markdown]
# # Improvement 2: Bigrams
# What if we tried using bigrams instead? How would using bigrams change the accuracy of our model? Usually including bigrams is a good model booster for any kind of Naive Bayes model, not just sentiment analysis. CountVectorizer makes it easy for us to input bigrams into our Naive Bayes model with a ngram_range parameter. The first value in the tuple specifies the lowest ngram we will track, and the second, the highest. In this case, we will consider both unigrams and bigrams. <br>

# %%
#Use bigrams with countvectorizer
vectorizer_bigrams = CountVectorizer(analyzer="word", ngram_range = (1,2), encoding='ISO-8859-1', lowercase=False)
train_features_bigrams = vectorizer_bigrams.fit_transform(train['Comments'])
test_features_bigrams  = vectorizer_bigrams.transform(test['Comments'])

# %%
#test the bigrams function worked as expected
vectorizer_bigrams.vocabulary_
# Out:
# {'RT': 6049,
#  'ecosmob': 11914,
#  'Ecosmob': 2454,
#  'Mobility': 5026,
#  'solutions': 17597,
#  'for': 12579,
#  'Banking': 1393,
#  'Microfinance': 4794,
#  'and': 8438,
#  'other': 16030,
#  'financial': 12455,
#  'institutions': 13834,
#  'help': 13237,
#  'in': 13500,
#  'improving': 13497,
#  'customer': 11371,
#  'experien': 12244,
#  'RT ecosmob': 6260,
#  'ecosmob Ecosmob': 11915,
#  'Ecosmob Mobility': 2455,
#  'Mobility solutions': 5027,
#  'solutions for': 17599,
#  'for Banking': 12588,
#  'Banking Microfinance': 1397,
#  'Microfinance and': 4898,
#  'and other': 8569,
#  'other financial': 16031,
#  'financial institutions': 12463,
#  'institutions help': 13846,
#  'help in': 13242,
#  'in improving': 13624,
#  'improving customer': 13498,
#  'customer experien': 11372,
#  'Project': 5896,
#  'have': 13168,
#  'big': 9239,
#  'future': 12842,
#  'is': 13988,
#  'believed': 9184,
#  'by': 9452,
#  'many': 14832,
#  'to': 18521,
#  'be': 9103,
#  'the': 18105,
#  'potential': 16457,
#  'key': 14287,
#  'helping': 13261,
#  'fight': 12407,
#  'even': 12189,
#  'most': 15300,
#  'st': 17688,
#  'https': 13380,
#  'co': 9737,
#  'DTLMxRZnr6': 2145,
#  'Project have': 5897,
#  'have big': 13174,
#  'big future': 9244,
#  'future Microfinance': 12843,
#  'Microfinance is': 4932,
#  'is believed': 14002,
#  'believed by': 9185,
#  'by many': 9476,
#  'many to': 14838,
#  'to be': 18584,
#  'be the': 9124,
#  'the potential': 18293,
#  'potential key': 16459,
#  'key to': 14291,
#  'to helping': 18640,
#  'helping fight': 13262,
#  'fight even': 12408,
#  'even the': 12190,
#  'the most': 18276,
#  'most st': 15305,
#  'st https': 17689,
#  'https co': 13381,
#  'co DTLMxRZnr6': 10011,
#  'Online': 5502,
#  'Yako': 7934,
#  'Bank': 1322,
#  'provides': 16721,
#  'convenient': 11221,
#  'safe': 17199,
#  'Services': 6752,
#  'you': 19744,
#  'manag': 14806,
#  'I4csg8ppFJ': 3403,
#  'Online Banking': 5503,
#  'Banking Yako': 1402,
#  'Yako Microfinance': 7935,
#  'Microfinance Bank': 4808,
#  'Bank provides': 1385,
#  'provides convenient': 16724,
#  'convenient and': 11222,
#  'and safe': 8594,
#  'safe Online': 17200,
#  'Banking Services': 1399,
#  'Services to': 6759,
#  'to help': 18639,
#  'help you': 13250,
#  'you manag': 19768,
#  'manag https': 14807,
#  'co I4csg8ppFJ': 10113,
#  'MICROFINANCE': 4492,
#  'EVENT': 2422,
#  '3rd': 394,
#  'BoP': 1549,
#  'Global': 3094,
#  'Network': 5261,
#  'Summit': 6987,
#  'April': 1084,
#  '18': 109,
#  '20': 177,
#  '2018': 222,
#  'New': 5267,
#  'Delhi': 2198,
#  'India': 3621,
#  's27AK1FgSt': 17176,
#  'MICROFINANCE EVENT': 4497,
#  'EVENT 3rd': 2423,
#  '3rd BoP': 398,
#  'BoP Global': 1550,
#  'Global Network': 3097,
#  'Network Summit': 5262,
#  'Summit April': 6988,
#  'April 18': 1085,
#  '18 20': 110,
#  '20 2018': 179,
#  '2018 New': 234,
#  'New Delhi': 5273,
#  'Delhi India': 2199,
#  'India https': 3628,
#  'co s27AK1FgSt': 10852,
#  'FINCA': 2633,
#  'rupertscofield': 17144,
#  'spoke': 17666,
#  'with': 19453,
#  'techweez': 18017,
#  'about': 8070,
#  'digitization': 11693,
#  'underway': 18991,
#  'microfinance': 14988,
#  'role': 17131,
#  'fintech': 12508,
#  'has': 13125,
#  'play': 16381,
#  'expa': 12233,
#  'RT FINCA': 6101,
#  'FINCA rupertscofield': 2648,
#  'rupertscofield spoke': 17148,
#  'spoke with': 17667,
#  'with techweez': 19522,
#  'techweez about': 18018,
#  'about the': 8088,
#  'the digitization': 18200,
#  'digitization underway': 11695,
#  'underway in': 18992,
#  'in microfinance': 13636,
#  'microfinance and': 15031,
#  'and the': 8609,
#  'the role': 18311,
#  'role fintech': 17132,
#  'fintech has': 12512,
#  'has to': 13166,
#  'to play': 18682,
#  'play in': 16382,
#  'in expa': 13616,
#  'oluabudu': 15842,
#  'Get': 3060,
#  'cash': 9569,
#  'loan': 14650,
#  'of': 15624,
#  'N200': 5164,
#  '000': 0,
#  'N2': 5161,
#  '5m': 483,
#  'For': 2889,
#  'salary': 17208,
#  'earners': 11878,
#  'who': 19383,
#  'live': 14628,
#  'work': 19582,
#  'Lagos': 4193,
#  'State': 6928,
#  'no': 15525,
#  'Collateral': 1938,
#  'or': 15981,
#  'Guarantor': 3208,
#  'nee': 15437,
#  'RT oluabudu': 6305,
#  'oluabudu Get': 15843,
#  'Get cash': 3061,
#  'cash loan': 9571,
#  'loan of': 14663,
#  'of N200': 15682,
#  'N200 000': 5165,
#  '000 to': 9,
#  'to N2': 18555,
#  'N2 5m': 5162,
#  '5m For': 484,
#  'For salary': 2897,
#  'salary earners': 17209,
#  'earners who': 11879,
#  'who live': 19395,
#  'live and': 14629,
#  'and work': 8625,
#  'work in': 19587,
#  'in Lagos': 13550,
#  'Lagos State': 4197,
#  'State with': 6930,
#  'with no': 19509,
#  'no Collateral': 15526,
#  'Collateral or': 1939,
#  'or Guarantor': 15983,
#  'Guarantor nee': 3209,
#  'PoojaMedia': 5803,
#  'From': 2946,
#  'being': 9172,
#  'an': 8398,
#  'influencer': 13751,
#  'bank': 9010,
#  'invited': 13976,
#  'as': 8788,
#  'sports': 17672,
#  'BBC': 1214,
#  'Africa': 824,
#  'their': 18351,
#  'Bur': 1630,
#  'RT PoojaMedia': 6174,
#  'PoojaMedia From': 5804,
#  'From being': 2948,
#  'being an': 9173,
#  'an influencer': 8420,
#  'influencer for': 13752,
#  'for microfinance': 12651,
#  'microfinance bank': 15037,
#  'bank to': 9038,
#  'to being': 18586,
#  'being invited': 9175,
#  'invited as': 13977,
#  'as sports': 8813,
#  'sports influencer': 17673,
#  'for BBC': 12587,
#  'BBC Africa': 1215,
#  'Africa for': 833,
#  'for their': 12676,
#  'their Lagos': 18352,
#  'Lagos Bur': 4194,
#  'WhatWorksVAWG': 7778,
#  'Read': 6356,
#  'latest': 14424,
#  'blog': 9294,
#  'from': 12761,
#  'Erin': 2546,
#  'Stern': 6945,
#  'LSHTM': 4169,
#  'on': 15848,
#  'impact': 13450,
#  'amp': 8355,
#  'gender': 12879,
#  'transformative': 18850,
#  'programmes': 16645,
#  'preventing': 16548,
#  'RT WhatWorksVAWG': 6223,
#  'WhatWorksVAWG Read': 7779,
#  'Read latest': 6361,
#  'latest blog': 14426,
#  'blog from': 9295,
#  'from Erin': 12767,
#  'Erin Stern': 2547,
#  'Stern LSHTM': 6946,
#  'LSHTM on': 4170,
#  'on the': 15901,
#  'the impact': 18240,
#  'impact of': 13455,
#  'of Microfinance': 15678,
#  'Microfinance amp': 4897,
#  'amp gender': 8383,
#  'gender transformative': 12881,
#  'transformative programmes': 18852,
#  'programmes for': 16646,
#  'for preventing': 12664,
#  'tipped': 18514,
#  'lending': 14504,
#  'consumer': 11184,
#  'protection': 16691,
#  'Qgay3pQjmN': 5981,
#  'via': 19148,
#  'NewTimesRwanda': 5287,
#  'Microfinance institutions': 4931,
#  'institutions tipped': 13855,
#  'tipped on': 18515,
#  'on lending': 15887,
#  'lending and': 14506,
#  'and consumer': 8505,
#  'consumer protection': 11186,
#  'protection https': 16694,
#  'co Qgay3pQjmN': 10289,
#  'Qgay3pQjmN via': 5982,
#  'via NewTimesRwanda': 19152,
#  'angelicafuentes': 8629,
#  'helps': 13265,
#  'low': 14731,
#  'income': 13699,
#  'sectors': 17282,
#  'society': 17577,
#  'equal': 12114,
#  'access': 8090,
#  'services': 17359,
#  'This': 7286,
#  'clear': 9698,
#  'example': 12212,
#  'RT angelicafuentes': 6238,
#  'angelicafuentes Microfinance': 8630,
#  'Microfinance helps': 4925,
#  'helps low': 13268,
#  'low income': 14733,
#  'income sectors': 13704,
#  'sectors of': 17284,
#  'of society': 15775,
#  'society have': 17578,
#  'have equal': 13179,
#  'equal access': 12116,
#  'access to': 8095,
#  'to financial': 18623,
#  'financial services': 12470,
#  'services This': 17360,
#  'This is': 7291,
#  'is clear': 14007,
#  'clear example': 9699,
#  'atmadiprayET': 8887,
#  'Here': 3316,
#  'why': 19402,
#  'Janalakshmi': 3851,
#  'Financial': 2786,
#  'takes': 17958,
#  'so': 17543,
#  'long': 14705,
#  'small': 17508,
#  'finance': 12428,
#  'transition': 18855,
#  'traKQNXuxe': 18815,
#  'economictime': 11907,
#  'RT atmadiprayET': 6243,
#  'atmadiprayET Here': 8888,
#  'Here why': 3321,
#  'why Janalakshmi': 19403,
#  'Janalakshmi Financial': 3852,
#  'Financial takes': 2817,
#  'takes so': 17959,
#  'so long': 17546,
#  'long to': 14707,
#  'to small': 18706,
#  'small finance': 17518,
#  'finance bank': 12432,
#  'bank transition': 9039,
#  'transition https': 18856,
#  'co traKQNXuxe': 10891,
#  'traKQNXuxe via': 18816,
#  'via economictime': 19157,
#  'lendwithcare': 14514,
#  'Our': 5569,
#  'partner': 16204,
#  'Pakistan': 5662,
#  'Akhuwat': 899,
#  'are': 8717,
#  'biggest': 9253,
#  'organisation': 16004,
#  'probably': 16573,
#  'largest': 14413,
#  'Isla': 3769,
#  'RT lendwithcare': 6293,
#  'lendwithcare Our': 14516,
#  'Our partner': 5575,
#  'partner in': 16206,
#  'in Pakistan': 13570,
#  'Pakistan Akhuwat': 5663,
#  'Akhuwat are': 902,
#  'are the': 8752,
#  'the biggest': 18182,
#  'biggest microfinance': 9256,
#  'microfinance organisation': 15096,
#  'organisation in': 16006,
#  'Pakistan and': 5670,
#  'and probably': 8580,
#  'probably the': 16575,
#  'the largest': 18257,
#  'largest Isla': 14414,
#  'texasnick310': 18044,
#  'Lynn': 4421,
#  'Forester': 2903,
#  'de': 11458,
#  'Rothschild': 6502,
#  '2006': 189,
#  'Appointed': 1075,
#  'member': 14926,
#  'UN': 7441,
#  'Advisors': 814,
#  'Group': 3179,
#  'Inclusive': 3607,
#  'Alfre': 913,
#  'RT texasnick310': 6319,
#  'texasnick310 Lynn': 18045,
#  'Lynn Forester': 4422,
#  'Forester de': 2904,
#  'de Rothschild': 11474,
#  'Rothschild 2006': 6503,
#  '2006 Appointed': 190,
#  'Appointed as': 1076,
#  'as member': 8807,
#  'member of': 14928,
#  'of the': 15785,
#  'the UN': 18163,
#  'UN Advisors': 7442,
#  'Advisors Group': 815,
#  'Group on': 3190,
#  'on Inclusive': 15859,
#  'Inclusive Financial': 3608,
#  'Financial Services': 2798,
#  'Services Alfre': 6754,
#  'Laura_B_Doering': 4211,
#  'How': 3372,
#  'do': 11744,
#  'personal': 16299,
#  'relationships': 16986,
#  'affect': 8179,
#  'In': 3568,
#  'new': 15475,
#  'paper': 16157,
#  'use': 19055,
#  'data': 11429,
#  'show': 17446,
#  'how': 13355,
#  'ties': 18502,
#  'RT Laura_B_Doering': 6143,
#  'Laura_B_Doering How': 4212,
#  'How do': 3380,
#  'do personal': 11754,
#  'personal relationships': 16301,
#  'relationships affect': 16987,
#  'affect lending': 8180,
#  'lending In': 14505,
#  'In new': 3591,
#  'new paper': 15484,
#  'paper use': 16161,
#  'use data': 19057,
#  'data from': 11433,
#  'from microfinance': 12786,
#  'microfinance to': 15129,
#  'to show': 18705,
#  'show how': 17447,
#  'how personal': 13364,
#  'personal ties': 16303,
#  'mmaqil': 15205,
#  'Majority': 4556,
#  'people': 16272,
#  'will': 19419,
#  'digital': 11680,
#  'wallet': 19242,
#  'smartphone': 17537,
#  'next': 15495,
#  'years': 19719,
#  'My': 5132,
#  'thoughts': 18463,
#  'FinancialInc': 2822,
#  'RT mmaqil': 6297,
#  'mmaqil Majority': 15207,
#  'Majority of': 4557,
#  'the people': 18289,
#  'people in': 16280,
#  'Pakistan will': 5681,
#  'will have': 19428,
#  'have digital': 13178,
#  'digital wallet': 11689,
#  'wallet on': 19244,
#  'on smartphone': 15900,
#  'smartphone in': 17538,
#  'in the': 13661,
#  'the next': 18280,
#  'next years': 15500,
#  'years My': 19720,
#  'My thoughts': 5135,
#  'thoughts on': 18464,
#  'on FinancialInc': 15857,
#  '6fk3hc1S9I': 523,
#  'via https': 19159,
#  'co 6fk3hc1S9I': 9877,
#  'ManyRivers_': 4605,
#  'providing': 16728,
#  'lift': 14580,
#  'poverty': 16478,
#  'welfare': 19328,
#  'across': 8134,
#  'Australia': 1161,
#  'it': 14096,
#  'requires': 17041,
#  'ter': 18038,
#  't3cKtHc0iH': 17937,
#  'ManyRivers_ providing': 4606,
#  'providing microfinance': 16735,
#  'to lift': 18659,
#  'lift people': 14581,
#  'people from': 16279,
#  'from poverty': 12791,
#  'poverty and': 16484,
#  'and welfare': 8621,
#  'welfare across': 19329,
#  'across Australia': 8136,
#  'Australia it': 1162,
#  'it requires': 14110,
#  'requires long': 17042,
#  'long ter': 14706,
#  'ter https': 18039,
#  'co t3cKtHc0iH': 10873,
#  'MOHANOKOR': 4507,
#  'Plc': 5792,
#  'caAN22Kqny': 9497,
#  'MOHANOKOR Microfinance': 4508,
#  'Microfinance Plc': 4868,
#  'Plc https': 5795,
#  'co caAN22Kqny': 10549,
#  'evI8dOnr48': 12182,
#  'Rwanda': 6531,
#  'co evI8dOnr48': 10589,
#  'evI8dOnr48 Rwanda': 12183,
#  'post': 16449,
#  'World': 7858,
#  'Benefits': 1462,
#  'Expansion': 2595,
#  'Having': 3287,
#  'healthy': 13220,
#  'economy': 11910,
#  'di': 11648,
#  'wLUSXBp30l': 19225,
#  'New post': 5283,
#  'post How': 16453,
#  'How the': 3386,
#  'the World': 18168,
#  'World Benefits': 7860,
#  'Benefits from': 1465,
#  'from the': 12799,
#  'the Expansion': 18132,
#  'Expansion of': 2597,
#  'Microfinance Having': 4836,
#  'Having healthy': 3289,
#  'healthy economy': 13222,
#  'economy is': 11913,
#  'is di': 14010,
#  'di https': 11653,
#  'co wLUSXBp30l': 10941,
#  'Grameen': 3148,
#  'under': 18970,
#  'fire': 12522,
#  'york': 19742,
#  'times': 18509,
#  '2A0H0fH5yr': 300,
#  'Grameen and': 3150,
#  'and microfinance': 8562,
#  'microfinance under': 15132,
#  'under fire': 18972,
#  'fire the': 12523,
#  'the new': 18279,
#  'new york': 15486,
#  'york times': 19743,
#  'times https': 18511,
#  'co 2A0H0fH5yr': 9779,
#  'china': 9669,
#  'made': 14774,
#  'spying': 17680,
#  'drones': 11813,
#  'Monitor': 5060,
#  '9HGqIOJWTj': 615,
#  'china made': 9670,
#  'made spying': 14777,
#  'spying drones': 17681,
#  'drones Microfinance': 11814,
#  'Microfinance Monitor': 4860,
#  'Monitor https': 5062,
#  'co 9HGqIOJWTj': 9929,
#  'MDC_Aus': 4450,
#  'Microcredit': 4780,
#  'footnote': 12577,
#  'major': 14781,
#  'banks': 9064,
#  'not': 15542,
#  'core': 11245,
#  'business': 9401,
#  'Its': 3799,
#  'window': 19440,
#  'dressing': 11806,
#  'designed': 11598,
#  'RT MDC_Aus': 6149,
#  'MDC_Aus Microcredit': 4451,
#  'Microcredit is': 4783,
#  'is footnote': 14018,
#  'footnote in': 12578,
#  'in major': 13633,
#  'major banks': 14782,
#  'banks not': 9078,
#  'not their': 15556,
#  'their core': 18361,
#  'core business': 11247,
#  'business Its': 9404,
#  'Its their': 3800,
#  'their window': 18369,
#  'window dressing': 19441,
#  'dressing Microcredit': 11807,
#  'is not': 14042,
#  'not designed': 15546,
#  'designed to': 11599,
#  'ecocreative': 11894,
#  'day': 11442,
#  'socent': 17555,
#  'pioneer': 16349,
#  'Yunus_Centre': 7980,
#  'GrameenFdn': 3153,
#  'at': 8837,
#  'Social': 6848,
#  'Business': 1640,
#  'Forum': 2911,
#  'RT ecocreative': 6259,
#  'ecocreative big': 11895,
#  'big day': 9241,
#  'day for': 11444,
#  'for socent': 12670,
#  'socent in': 17556,
#  'in Australia': 13514,
#  'Australia with': 1163,
#  'with microfinance': 19506,
#  'microfinance pioneer': 15103,
#  'pioneer Yunus_Centre': 16350,
#  'Yunus_Centre of': 7986,
#  'of GrameenFdn': 15662,
#  'GrameenFdn at': 3154,
#  'at the': 8880,
#  'the Social': 18160,
#  'Social Business': 6849,
#  'Business Forum': 1645,
#  'Fortunate': 2909,
#  'able': 8067,
#  'hear': 13223,
#  'Prof': 5873,
#  'Yunus': 7973,
#  'this': 18426,
#  'morning': 15295,
#  'pathway': 16236,
#  'out': 16082,
#  'Grame': 3146,
#  'HrOQvRIoCt': 3389,
#  'Fortunate to': 2910,
#  'be able': 9105,
#  'able to': 8068,
#  'to hear': 18638,
#  'hear Yunus_Centre': 13224,
#  'Yunus_Centre Prof': 7982,
#  'Prof Yunus': 5876,
#  'Yunus this': 7979,
#  'this morning': 18441,
#  'morning Microfinance': 15296,
#  'Microfinance pathway': 4941,
#  'pathway out': 16237,
#  'out of': 16089,
#  'of poverty': 15767,
#  'poverty Grame': 16479,
#  'Grame https': 3147,
#  'co HrOQvRIoCt': 10106,
#  '25ème': 286,
#  'réunion': 17168,
#  'du': 11818,
#  'Comité': 1952,
#  'National': 5239,
#  'coordination': 11241,
#  'des': 11579,
#  'Activités': 786,
#  'Une': 7513,
#  'inclusive': 13694,
#  'pour': 16462,
#  'accès': 8122,
#  'DtreM8oH2b': 2354,
#  '25ème réunion': 287,
#  'réunion du': 17169,
#  'du Comité': 11821,
#  'Comité National': 1953,
#  'National de': 5242,
#  'de coordination': 11480,
#  'coordination des': 11242,
#  'des Activités': 11582,
#  'Activités de': 787,
#  'de Microfinance': 11471,
#  'Microfinance Une': 4890,
#  'Une finance': 7514,
#  'finance inclusive': 12441,
#  'inclusive pour': 13696,
#  'pour accès': 16465,
#  'accès https': 8124,
#  'co DtreM8oH2b': 10019,
#  'kleosMFG': 14312,
#  'snapshot': 17539,
#  'some': 17608,
#  'our': 16051,
#  'inspiring': 13811,
#  'hardworking': 13121,
#  'entrepreneurs': 12102,
#  'Uganda': 7497,
#  'benefited': 9202,
#  'your': 19781,
#  'generous': 12889,
#  'donations': 11784,
#  'RT kleosMFG': 6291,
#  'kleosMFG snapshot': 14316,
#  'snapshot of': 17540,
#  'of some': 15776,
#  'some of': 17612,
#  'of our': 15763,
#  'our inspiring': 16063,
#  'inspiring hardworking': 13812,
#  'hardworking entrepreneurs': 13122,
#  'entrepreneurs in': 12106,
#  'in Uganda': 13586,
#  'Uganda who': 7501,
#  'who have': 19391,
#  'have benefited': 13173,
#  'benefited from': 9203,
#  'from your': 12804,
#  'your generous': 19790,
#  'generous donations': 12891,
#  'been': 9142,
#  'published': 16749,
#  'GeorgMedia': 3048,
#  'tJ9DoYuvlq': 17942,
#  'Microfinance has': 4923,
#  'has been': 13133,
#  'been published': 9154,
#  'published on': 16752,
#  'on GeorgMedia': 15858,
#  'GeorgMedia https': 3049,
#  'co tJ9DoYuvlq': 10878,
#  'QewidPJQVK': 5980,
#  'Microfinance https': 4926,
#  'co QewidPJQVK': 10288,
#  'Prosperousca1': 5909,
#  'What': 7769,
#  'insightful': 13794,
#  'Thanks': 7179,
#  'Mr': 5085,
#  'Markschreiner': 4643,
#  'Director': 2283,
#  'SCOROCD': 6581,
#  'giving': 12940,
#  'insights': 13796,
#  'bigdata': 9248,
#  'can': 9507,
#  'used': 19060,
#  'RT Prosperousca1': 6178,
#  'Prosperousca1 What': 5915,
#  'What an': 7771,
#  'an insightful': 8423,
#  'insightful day': 13795,
#  'day Thanks': 11443,
#  'Thanks Mr': 7180,
#  'Mr Markschreiner': 5091,
#  'Markschreiner Director': 4644,
#  'Director SCOROCD': 2288,
#  'SCOROCD for': 6582,
#  'for giving': 12641,
#  'giving insights': 12941,
#  'insights on': 13797,
#  'on how': 15880,
#  'how bigdata': 13361,
#  'bigdata can': 9249,
#  'can be': 9512,
#  'be used': 9126,
#  'used to': 19064,
#  'revoir': 17083,
#  'Finance': 2766,
#  'Le': 4218,
#  'sud': 17854,
#  'africain': 8189,
#  'Goodwell': 3123,
#  'investit': 13935,
#  'dans': 11418,
#  'une': 18995,
#  'société': 17582,
#  'néerlandaise': 15587,
#  'fournissant': 12732,
#  'logiciels': 14703,
#  'aux': 8933,
#  '5iYBEI6Us8': 481,
#  'revoir Finance': 17084,
#  'Finance Le': 2770,
#  'Le sud': 4225,
#  'sud africain': 17855,
#  'africain Goodwell': 8190,
#  'Goodwell investit': 3124,
#  'investit dans': 13936,
#  'dans une': 11422,
#  'une société': 18999,
#  'société néerlandaise': 17584,
#  'néerlandaise fournissant': 15588,
#  'fournissant des': 12733,
#  'des logiciels': 11589,
#  'logiciels aux': 14704,
#  'aux https': 8936,
#  'co 5iYBEI6Us8': 9857,
#  'With': 7810,
#  'loans': 14671,
#  'literacy': 14622,
#  'training': 18830,
#  'village': 19174,
#  'partners': 16210,
#  'start': 17706,
#  'own': 16117,
#  'businesses': 9421,
#  'earn': 11875,
#  'ui8P8THFNS': 18944,
#  'With microfinance': 7821,
#  'microfinance loans': 15086,
#  'loans and': 14677,
#  'and financial': 8528,
#  'financial literacy': 12465,
#  'literacy training': 14625,
#  'training our': 18836,
#  'our village': 16079,
#  'village partners': 19175,
#  'partners can': 16214,
#  'can start': 9525,
#  'start their': 17711,
#  'their own': 18366,
#  'own businesses': 16120,
#  'businesses earn': 9424,
#  'earn https': 11877,
#  'co ui8P8THFNS': 10907,
#  'wolbj': 19538,
#  'Digibyte': 2261,
#  'News': 5288,
#  'dgb': 11646,
#  'digitalasset': 11690,
#  'multialog': 15323,
#  'payments': 16249,
#  'crypto': 11344,
#  'blockchain': 9278,
#  'DigiByte': 2259,
#  'USD': 7483,
#  'Adoption': 802,
#  'sma': 17507,
#  'RT wolbj': 6333,
#  'wolbj Digibyte': 19539,
#  'Digibyte in': 2262,
#  'the News': 18150,
#  'News dgb': 5289,
#  'dgb digitalasset': 11647,
#  'digitalasset multialog': 11691,
#  'multialog payments': 15324,
#  'payments crypto': 16250,
#  'crypto blockchain': 11345,
#  'blockchain DigiByte': 9279,
#  'DigiByte microfinance': 2260,
#  'microfinance USD': 15022,
#  'USD Adoption': 7487,
#  'Adoption sma': 803,
#  'we': 19283,
#  'sponsor': 17670,
#  'projects': 16658,
#  'like': 14583,
#  'CAk3f7nCtG': 1703,
#  'ensiamedia': 12071,
#  'ibrahimthiaw': 13421,
#  'UNEP': 7452,
#  'sistema_bio': 17485,
#  'U19EznjMt2': 7421,
#  'How can': 3378,
#  'can we': 9527,
#  'we sponsor': 19298,
#  'sponsor projects': 17671,
#  'projects like': 16663,
#  'like this': 14594,
#  'this https': 18433,
#  'co CAk3f7nCtG': 9991,
#  'CAk3f7nCtG via': 1704,
#  'via ensiamedia': 19158,
#  'ensiamedia ibrahimthiaw': 12072,
#  'ibrahimthiaw UNEP': 13422,
#  'UNEP sistema_bio': 7453,
#  'sistema_bio https': 17486,
#  'co U19EznjMt2': 10363,
#  'Mobile': 5019,
#  'Technology': 7131,
#  'It': 3785,
#  'Can': 1780,
#  'Benefit': 1460,
#  '9I1QASalqc': 616,
#  'Mobile Technology': 5023,
#  'Technology and': 7132,
#  'and How': 8459,
#  'How It': 3374,
#  'It Can': 3786,
#  'Can Benefit': 1782,
#  'Benefit Microfinance': 1461,
#  'Microfinance Banking': 4809,
#  'Banking amp': 1403,
#  'amp Finance': 8363,
#  'Finance New': 2774,
#  'New Business': 5271,
#  'Business https': 1654,
#  'co 9I1QASalqc': 9930,
#  'uncensored': 18964,
#  'CryptoCurrency': 2081,
#  'Nano': 5233,
#  'cryptocurrency': 11351,
#  'case': 9564,
#  'DiebW4biie': 2256,
#  'uncensored CryptoCurrency': 18965,
#  'CryptoCurrency Nano': 2082,
#  'Nano cryptocurrency': 5234,
#  'cryptocurrency microfinance': 11356,
#  'microfinance use': 15133,
#  'use case': 19056,
#  'case microfinance': 9566,
#  'microfinance https': 15071,
#  'co DiebW4biie': 10015,
#  'fnfi_togo': 12552,
#  'Projet': 5900,
#  'Appui': 1079,
#  'la': 14362,
#  'que': 16808,
#  'couvre': 11293,
#  'ce': 9584,
#  'financement': 12446,
#  'vise': 19186,
#  'accompagner': 8100,
#  'primo': 16554,
#  'Plus': 5799,
#  '2500': 284,
#  'micr': 14965,
#  'RT fnfi_togo': 6272,
#  'fnfi_togo Le': 12553,
#  'Le Projet': 4220,
#  'Projet Appui': 5901,
#  'Appui la': 1080,
#  'la Microfinance': 14370,
#  'Microfinance que': 4946,
#  'que couvre': 16809,
#  'couvre ce': 11294,
#  'ce financement': 9585,
#  'financement vise': 12448,
#  'vise accompagner': 19187,
#  'accompagner des': 8101,
#  'des primo': 11592,
#  'primo entrepreneurs': 16555,
#  'entrepreneurs Plus': 12103,
#  'Plus de': 5800,
#  'de 2500': 11460,
#  '2500 micr': 285,
#  'Founded': 2923,
#  '2001': 187,
#  'FincaZambia': 2838,
#  'today': 18743,
#  'regulated': 16975,
#  'deposit': 11569,
#  'taking': 17960,
#  'organization': 16015,
#  'LWcL3rAUS0': 4176,
#  'FinancialInclusion': 2823,
#  'Founded in': 2924,
#  'in 2001': 13503,
#  '2001 FincaZambia': 188,
#  'FincaZambia today': 2839,
#  'today is': 18750,
#  'is regulated': 14056,
#  'regulated deposit': 16976,
#  'deposit taking': 11570,
#  'taking microfinance': 17961,
#  'microfinance organization': 15097,
#  'organization https': 16016,
#  'co LWcL3rAUS0': 10170,
#  'LWcL3rAUS0 FinancialInclusion': 4177,
#  'institutio': 13822,
#  '6HiOFUzoUo': 511,
#  'revoir Le': 17085,
#  'aux institutio': 8937,
#  'institutio https': 13823,
#  'co 6HiOFUzoUo': 9869,
#  'w5rq07vVo2': 19220,
#  'co w5rq07vVo2': 10936,
#  'UNRWA': 7464,
#  'More': 5068,
#  'than': 18052,
#  '15': 91,
#  '890': 583,
#  'female': 12387,
#  'Palestine': 5685,
#  'refugees': 16970,
#  'received': 16934,
#  '2017': 212,
#  'IWD2018': 3501,
#  'TimeIsNow': 7310,
#  'DignityIsPriceless': 2270,
#  'RT UNRWA': 6214,
#  'UNRWA More': 7465,
#  'More than': 5073,
#  ...}

# %%
#train your data set using multinomial NB from sklearn library
nb = MultinomialNB()
nb.fit(train_features_bigrams, train['Sentiment'])
# Out:
# MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)

# %%
#test your data set on your test data
preds = nb.predict(test_features_bigrams)

#print the accuracy of your model
accuracy = (preds == test['Sentiment'])
'Accuracy : {:.2%}'.format(accuracy.sum() / len(accuracy))
# Out:
# 'Accuracy : 87.64%'

# %% [markdown]
# As expected, adding bigrams slightly improves the accuracy of our Naive Bayes model.<br>

# %% [markdown]
# # Improvement 3: Binary count Naive Bayes
#
# Another improvement specific to sentiment analysis is binary count. Using binary count Naive Bayes isn't guaranteed to improve your model, but it frequently does when sentiment analysis is involved. To incorporate this to our model, we will update the text_process function to remove duplicates.

# %%
#update the text_process function to get rid of duplicates in the reviews

def text_process_binary(text):
    '''
    Takes in a string of text, then performs the following:
    1. Remove all punctuation
    2. Remove all stopwords
    3. Return the cleaned lemmatized text as a list of words
    '''
    nopunc = [char for char in text if char not in string.punctuation]
    nopunc = ''.join(nopunc)
    
    nostopwords = [lemmatizer.lemmatize(word) for word in nopunc.split() if word.lower() not in stopwords.words('english')]
    return list(set(nostopwords))

# %%
#Use bigrams with countvectorizer
vectorizer_binary = CountVectorizer(analyzer=text_process_binary)
train_features_binary = vectorizer_binary.fit_transform(train['Comments'])
test_features_binary =  vectorizer_binary.transform(test['Comments'])

# %%
#train your data set using multinomial NB from sklearn library
nb = MultinomialNB()
nb.fit(train_features_binary, train['Sentiment'])
# Out:
# MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)

# %%
#test your data set on your test data
preds = nb.predict(test_features_binary)

#print the accuracy of your model
accuracy = (preds == test['Sentiment'])
'Accuracy : {:.2%}'.format(accuracy.sum() / len(accuracy))
# Out:
# 'Accuracy : 84.39%'

# %% [markdown]
# Unfortunately, adding binary count does not improve the accuracy of our Naive Bayes model in this sample of data.<br>

# %% [markdown]
# # Improvement 4: Dealing with informal text
# Lastly, another improvement specific to sentiment analysis is to deal more specifically with informal test. Common informal text related to sentiment analysis are emojis and informal text, like all caps, to represent excitement. To deal with emojis, we will update our text_process function, and to deal with capitalization, we will turn off the lowercase parameter in the CountVectorizer initializer. Given wordnet did not consider capitalization and emojis when classifying the data in the first place, this method will unfortunately probably not change the accuracy of the model.

# %%
#all capitalized phrases are taken into account as a different word, but accounting for simple emojis is helpful

def text_process_informal(text):
    '''
    Takes in a string of text, then performs the following:
    1. Remove all punctuation
    2. Remove all stopwords
    3. Return the cleaned text as a list of lemmatized words
    '''
    nopunc = [text[i] for i in range(len(text)) if (text[i] not in string.punctuation) or \
              (text[i:i+2] in [":(", ":)"]) or (text[i]+text[i-1] in [":(", ":)"]) or \
              (text[i:i+2] in ["(:", "):"]) or (text[i]+text[i-1] in ["(:", "):"])]
    nopunc = ''.join(nopunc)
    
    nostopwords = [lemmatizer.lemmatize(word) for word in nopunc.split() if word.lower() not in stopwords.words('english')]
    return nostopwords

# %%
#test on a sample text  to make sure the update worked
text = ":I LOVE love BBQ chicken pizza. I eat it every day, but sometimes I wonder if I'm being unhealthy :) :("
text_process_informal(text)
# Out:
# [':I',
#  'LOVE',
#  'love',
#  'BBQ',
#  'chicken',
#  'pizza',
#  'eat',
#  'every',
#  'day',
#  'sometimes',
#  'wonder',
#  'Im',
#  'unhealthy',
#  ':)',
#  ':(']

# %%
#Use bigrams with countvectorizer
vectorizer_informal = CountVectorizer(analyzer=text_process_informal, lowercase = False)
train_features_informal = vectorizer_informal.fit_transform(train['Comments'])
test_features_informal =  vectorizer_informal.transform(test['Comments'])

# %%
#train your data set using multinomial NB from sklearn library
nb = MultinomialNB()
nb.fit(train_features_informal, train['Sentiment'])
# Out:
# MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)

# %%
#test your data set on your test data
preds = nb.predict(test_features_informal)

#print the accuracy of your model
accuracy = (preds == test['Sentiment'])
'Accuracy : {:.2%}'.format(accuracy.sum() / len(accuracy))
# Out:
# 'Accuracy : 84.85%'

# %% [markdown]
# As predicted, the accuracy did not change much from basic Naive Bayes.

# %% [markdown]
# # Conclusion
#
# We've reviewed the basics of Naive Bayes and investigated how improvements can be used in the case of sentiment analysis. Our results are a bit skewed due to the methodology of original classification, but it seems that using bigrams (or any form of ngrams) was the most effective way to improve the model.
#
# We hope that this module has taught you that real life data is messy, and that building a model is more an art than a science. There are many kinds of small improvements you can make to a Naive Bayes model, and it often depends on the nature of your data. For instance, if you know the text you're using will be particularly informal, it may be good to adapt your analyzer function to account for those informalities. If the text is not informal, this adjustment will not change much to your model accuracy.

# %% [markdown]
# Sources: https://medium.com/tensorist/classifying-yelp-reviews-using-nltk-and-scikit-learn-c58e71e962d9, https://www.dataquest.io/blog/naive-bayes-tutorial/, http://nlpforhackers.io/sentiment-analysis-intro/, http://scikit-learn.org/stable/auto_examples/model_selection/plot_confusion_matrix.html <br>
